# %% [markdown]
# # Audible Insights — project walkthrough
# This notebook is a lightweight place to inspect the cleaned data and try the recommendation functions outside Streamlit. The production app uses the same code from `src/`.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.app_helpers import load_data, load_bundle
from src.recommender import similar_books, genre_recommendations, hidden_gems
df = load_data()
df.head()

# %%
df[['rating', 'review_count', 'price', 'listening_minutes']].describe()

# %%
bundle = load_bundle(df)
bundle.metrics

# %%
idx = df.index[df['book_name'].str.contains('Ikigai', case=False, na=False)][0]
similar_books(df, bundle, idx, n=5)[['book_name', 'author', 'rating', 'primary_genre', 'recommendation_score']]

# %%
hidden_gems(df, 10)[['book_name', 'author', 'rating', 'review_count', 'primary_genre']]
